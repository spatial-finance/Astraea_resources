# %% [markdown]
# # Build Landsat-8 TIR Macro-localization Deep Learning Model
#
# This notebook trains models to classify Landsat 8 TIR Band 10 image chips into cement and landcover.
#
# TBD more...
#
# ## Install Earlier Version of fastai

# %%
# !pip install fastai==1.0.61
# Out:
# Collecting fastai==1.0.61
#   Downloading fastai-1.0.61-py3-none-any.whl (239 kB)
#      |████████████████████████████████| 239 kB 24.6 MB/s eta 0:00:01
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (4.9.1)
# Requirement already satisfied: pandas in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (1.1.2)
# Requirement already satisfied: pyyaml in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (5.3.1)
# Requirement already satisfied: torchvision in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (0.7.0)
# Requirement already satisfied: spacy>=2.0.18; python_version < "3.8" in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (2.3.2)
# Requirement already satisfied: torch>=1.0.0 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (1.6.0)
# Requirement already satisfied: numexpr in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (2.7.1)
# Requirement already satisfied: packaging in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (20.4)
# Requirement already satisfied: bottleneck in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (1.3.2)
# Requirement already satisfied: scipy in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (1.5.2)
# Requirement already satisfied: nvidia-ml-py3 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (7.352.0)
# Requirement already satisfied: matplotlib in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (3.3.2)
# Requirement already satisfied: Pillow in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (7.2.0)
# Requirement already satisfied: requests in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (2.24.0)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (1.19.1)
# Requirement already satisfied: fastprogress>=0.2.1 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from fastai==1.0.61) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from beautifulsoup4->fastai==1.0.61) (2.0.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from pandas->fastai==1.0.61) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from pandas->fastai==1.0.61) (2.8.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (4.49.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (1.1.3)
# Requirement already satisfied: thinc==7.4.1 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (7.4.1)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (0.4.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (1.0.2)
# Requirement already satisfied: setuptools in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (49.6.0.post20200814)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (3.0.2)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (2.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (0.8.0)
# Requirement already satisfied: future in /opt/conda/envs/earthai/lib/python3.7/site-packages (from torch>=1.0.0->fastai==1.0.61) (0.18.2)
# Requirement already satisfied: six in /opt/conda/envs/earthai/lib/python3.7/site-packages (from packaging->fastai==1.0.61) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from packaging->fastai==1.0.61) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from matplotlib->fastai==1.0.61) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from matplotlib->fastai==1.0.61) (1.2.0)
# Requirement already satisfied: certifi>=2020.06.20 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from matplotlib->fastai==1.0.61) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from requests->fastai==1.0.61) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from requests->fastai==1.0.61) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from requests->fastai==1.0.61) (2.10)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /opt/conda/envs/earthai/lib/python3.7/site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/envs/earthai/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.0.18; python_version < "3.8"->fastai==1.0.61) (3.1.0)
# Installing collected packages: fastai
#   Attempting uninstall: fastai
#     Found existing installation: fastai 2.0.13
#     Uninstalling fastai-2.0.13:
#       Successfully uninstalled fastai-2.0.13
# Successfully installed fastai-1.0.61

# %% [markdown]
# ## Import Libraries

# %%
import os
import random
import glob

import boto3

import pandas as pd
import numpy as np

import sklearn.model_selection
import torch
from torch import nn

from fastai import *
from fastai.vision import *
from fastai.widgets import ClassConfusion

# %% [markdown]
# ## Download .tar File From S3 Bucket and Extract Contents
#
# This tar file contains normalized PNGs for cement and landcover, divided into train and validate sets.

# %%
AWS_SOURCE_PATH = 'L8-TIR-macro-localization-model-build3'
IMG_DIR = '/scratch/ALD_L8_TIR_chips_v4p1_train3_cement_binary'

# Output
AWS_MODEL_PATH = 'L8-TIR-model-results3'

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('sfi-shared-assets')

bucket.download_file(str(Path(AWS_SOURCE_PATH, IMG_DIR.split('/')[-1]+'.tar')), 
                     IMG_DIR+'.tar')

# %%
unix_code = 'tar -C /scratch/ -xf '+IMG_DIR+'.tar'
os.system(unix_code)
# Out:
# 0

# %% [markdown]
# ## Set Random Seeds
# Set random seeds to ensure reproducibility.

# %%
def set_random_seed(seed=42):
    random.seed(seed)

    torch.manual_seed(seed)

    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False

    np.random.seed(seed)
    
set_random_seed()

# %% [markdown]
# ## Read in, Augment and Partition Image Data
# Read in image files and augment them using flipping, rotation, zoom, lighting, warping, and affine transformations. Partition using fixed random seed for reprodicibility.

# %%
tfms = get_transforms(do_flip=True,
                      flip_vert=True, 
                      max_lighting=None, 
                      max_zoom=1.5, 
                      max_warp=0.2)

data = (ImageDataBunch.from_folder(IMG_DIR, train='train', valid='validate', 
                                   ds_tfms=tfms, bs=16, num_workers=0, seed=42)
        .normalize(imagenet_stats))

# %% [markdown]
# Display class-wise counts for training and validation sets.

# %%
def get_classwise_counts(items, classes):
    series = pd.value_counts(items).sort_index()
    series.index = classes
    
    return series

for subset, label in zip((data.train_ds, data.valid_ds), ('Training set', 'Validation set')):
    print('--- {} ---'.format(label))
    print(get_classwise_counts(subset.y.items, subset.classes))
# Out:
# --- Training set ---
# cement        910
# landcover    2116
# dtype: int64
# --- Validation set ---
# cement       228
# landcover    529
# dtype: int64

# %% [markdown]
# For exploratory purposes, display a sample of images from a single training batch.

# %%
data.show_batch(rows=4, figsize=(10,10))

# %% [markdown]
# ## Common Setup for Pre-trained Models

# %%
results = {}
interpretations = {}

# %%
weights = [1, 1]
# Replace the weight for the most abundant class with a smaller value
weights[np.argmax(get_classwise_counts(data.train_ds.y.items, data.train_ds.classes).values)] = 0.2
class_weights = torch.FloatTensor(weights).cuda()
loss_w = nn.CrossEntropyLoss(weight=class_weights)

# %%
weights
# Out:
# [1, 0.2]

# %%
# Instantiate metrics
recall = Recall()
precision = Precision()
# fbeta = MultiLabelFbeta(beta =1)
fbeta = FBeta()
metrics_all = [accuracy, recall, precision, fbeta]
metrics_labels = ['Accuracy', 'Recall', 'Precision', 'Fbeta']

# %% [markdown]
# ## Functions to Tune Learning Rate
#
# Tunes the learning rate based on Smith's (2015) range test.

# %%
def find_learning_rate(learner, show_plot=True):
    learner.lr_find()
    if show_plot:
        learner.recorder.plot()

# %%
def fit_recall_optimised(learner, n_epochs, max_learning_rate, model_filename):
    learner.fit_one_cycle(n_epochs, max_learning_rate,
                          callbacks=[callbacks.SaveModelCallback(learner, every='improvement', monitor='recall', name=model_filename)])

    learner.recorder.plot_losses() #, learner.recorder.plot_metrics()
    interpretation = ClassificationInterpretation.from_learner(learner)
    interpretation.plot_confusion_matrix(title='Confusion matrix', dpi=100)
    
    return interpretation

# %%
def get_statistics(learner):
    return dict(zip(metrics_labels, np.array(learner.validate(metrics=metrics_all))[1:]))

# %% [markdown]
# ## Run 1 - Resnet50

# %% [markdown]
# Adapt Resnet50 using a weighted cross entropy as a custom loss function and using mixup to train the model. In addition, we will optimise models for recall, by selecting among training epochs.

# %% [markdown]
# ### Define Learner (Resnet50)

# %%
learner = cnn_learner(data, 
                      models.resnet50,
                      # transfer learning on
                      pretrained=True,
                      # loss_func = LabelSmoothingCrossEntropy(), 
                      # class weighted cross entropy loss
                      loss_func=loss_w,
                      metrics=metrics_all,
                      opt_func=optim.Adam,
                      # batch norm at the end of the CNN
                      bn_final=True,
                      # nice callback for plotting loss for training and 
                      # validation during fitting 
                      # followed by mixup
                      callback_fns=ShowGraph).mixup()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /home/jovyan/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))

# %% [markdown]
# ### Tune Learning Rate (Resnet50)

# %%
find_learning_rate(learner)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='98' class='' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       51.85% [98/189 00:07<00:07 0.3277]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ### Train Resnet50 with initial (high) learning rate
#
# Based on the range test, a learning rate of 1E-02 appears to be reasonable, owing to the magnitude and slope of the associated loss.

# %%
fit_recall_optimised(learner, n_epochs=25, max_learning_rate=1e-02, model_filename='resnet_temp')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.265947</td>
#       <td>0.274727</td>
#       <td>0.677675</td>
#       <td>0.669187</td>
#       <td>0.836879</td>
#       <td>0.697125</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.250936</td>
#       <td>0.233081</td>
#       <td>0.648613</td>
#       <td>0.604915</td>
#       <td>0.848806</td>
#       <td>0.641797</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.234177</td>
#       <td>0.202098</td>
#       <td>0.731836</td>
#       <td>0.680529</td>
#       <td>0.913706</td>
#       <td>0.717132</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0
td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with recall value: 0.6691871285438538.
# Better model found at epoch 2 with recall value: 0.6805292963981628.
# Better model found at epoch 3 with recall value: 0.6918714642524719.
# Better model found at epoch 8 with recall value: 0.739130437374115.
# Better model found at epoch 9 with recall value: 0.8676748871803284.

# %% [markdown]
# ### Determine new learning rate (Resnet50)
#
# Fine tune the entire model. We perform this by unfreezing the model, then repeating the learning rate range test.

# %%
# load the model with the best recall
learner.load('resnet_temp')
learner.unfreeze()
find_learning_rate(learner)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.38% [99/189 00:08<00:07 0.3247]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ### Retrain Resnet50 with low learning rate
#
# Based on the range test, further train the model using a learning rate of 10E-4.

# %%
fit_recall_optimised(learner, n_epochs=10, max_learning_rate=1e-04, model_filename='resnet_temp')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.204432</td>
#       <td>0.169508</td>
#       <td>0.788639</td>
#       <td>0.756144</td>
#       <td>0.928074</td>
#       <td>0.785238</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.203698</td>
#       <td>0.172434</td>
#       <td>0.780713</td>
#       <td>0.752363</td>
#       <td>0.919169</td>
#       <td>0.780698</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.202614</td>
#       <td>0.173840</td>
#       <td>0.770145</td>
#       <td>0.716446</td>
#       <td>0.940447</td>
#       <td>0.752283</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.210087</td>
#       <td>0.171924</td>
#       <td>0.656539</td>
#       <td>0.525520</td>
#       <td>0.968641</td>
#       <td>0.578444</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.201960</td>
#       <td>0.169419</td>
#       <td>0.764861</td>
#       <td>0.718336</td>
#       <td>0.929095</td>
#       <td>0.752475</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.208038</td>
#       <td>0.166913</td>
#       <td>0.738441</td>
#       <td>0.672968</td>
#       <td>0.934383</td>
#       <td>0.712855</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.205180</td>
#       <td>0.166775</td>
#       <td>0.742404</td>
#       <td>0.689981</td>
#       <td>0.921717</td>
#       <td>0.726513</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.200160</td>
#       <td>0.168993</td>
#       <td>0.750330</td>
#       <td>0.701323</td>
#       <td>0.922886</td>
#       <td>0.736696</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.202606</td>
#       <td>0.164804</td>
#       <td>0.734478</td>
#       <td>0.665406</td>
#       <td>0.936170</td>
#       <td>0.706260</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.198662</td>
#       <td>0.164803</td>
#       <td>0.741083</td>
#       <td>0.678639</td>
#       <td>0.932468</td>
#       <td>0.717713</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with recall value: 0.7561436891555786.

# %% [markdown]
# ### Retrain Resnet50 from best recall-optimized model
#
# Load the best recall-optimised model, freeze and re-train.

# %%
learner.load('resnet_temp')
learner.freeze()
find_learning_rate(learner)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.38% [99/189 00:07<00:06 0.2512]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
fit_recall_optimised(learner, n_epochs=10, max_learning_rate=7e-04, model_filename='resnet_temp')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.219653</td>
#       <td>0.168866</td>
#       <td>0.774108</td>
#       <td>0.735350</td>
#       <td>0.926190</td>
#       <td>0.766956</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.210384</td>
#       <td>0.170079</td>
#       <td>0.759577</td>
#       <td>0.695652</td>
#       <td>0.946015</td>
#       <td>0.734531</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.206512</td>
#       <td>0.171572</td>
#       <td>0.743725</td>
#       <td>0.672968</td>
#       <td>0.944297</td>
#       <td>0.713999</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0
td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.194858</td>
#       <td>0.155906</td>
#       <td>0.799207</td>
#       <td>0.765595</td>
#       <td>0.935335</td>
#       <td>0.794429</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.197224</td>
#       <td>0.157603</td>
#       <td>0.801849</td>
#       <td>0.775047</td>
#       <td>0.929705</td>
#       <td>0.801721</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.192873</td>
#       <td>0.157706</td>
#       <td>0.805812</td>
#       <td>0.778828</td>
#       <td>0.932127</td>
#       <td>0.805317</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.198795</td>
#       <td>0.155343</td>
#       <td>0.783355</td>
#       <td>0.739130</td>
#       <td>0.937650</td>
#       <td>0.771812</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with recall value: 0.778827965259552.
# Better model found at epoch 2 with recall value: 0.7863894104957581.
# Better model found at epoch 3 with recall value: 0.8071833848953247.
# Better model found at epoch 4 with recall value: 0.8128544688224792.

# %%
learner.export(str(Path('resnet50_cement_binary_final.pkl')))
#results['resnet'] = get_statistics(learner)
#results['resnet']

# %%
pred, actual = learner.get_preds(ds_type=DatasetType.Train)
pred = np.array(pred)

# %% [markdown]
# ## Run 2 - VGG13

# %% [markdown]
# Adapt VGG13 using a weighted cross entropy as a custom loss function and using mixup to train the model. In addition, we will optimise models for recall, by selecting among training epochs.
#
# ### Define Learner (VGG13)

# %%
learner = cnn_learner(data, 
                      models.vgg13_bn,
                      # transfer learning on
                      pretrained=True,
                      # loss_func = LabelSmoothingCrossEntropy(), 
                      # class weighted cross entropy loss
                      loss_func=loss_w,
                      metrics=metrics_all,
                      opt_func=optim.Adam,
                      # batch norm at the end of the CNN
                      bn_final=True,
                      # nice callback for plotting loss for training and 
                      # validation during fitting 
                      # followed by mixup
                      callback_fns=ShowGraph).mixup()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg13_bn-abd245e5.pth" to /home/jovyan/.cache/torch/hub/checkpoints/vgg13_bn-abd245e5.pth
# HBox(children=(FloatProgress(value=0.0, max=532246301.0), HTML(value='')))

# %% [markdown]
# ### Tune Learning Rate (VGG13)
#
# Tune the learning rate based on Smith's (2015) range test.

# %%
find_learning_rate(learner)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.38% [99/189 00:04<00:03 0.3318]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ### First Round of VGG13 Training with High Learning Rate
#
# Based on the range test, a learning rate of 1E-02 appears to be reasonable, owing to the magnitude and slope of the associated loss.

# %%
fit_recall_optimised(learner, n_epochs=25, max_learning_rate=1e-02, model_filename='vgg_temp')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.287589</td>
#       <td>0.260119</td>
#       <td>0.663144</td>
#       <td>0.654064</td>
#       <td>0.827751</td>
#       <td>0.682715</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.259649</td>
#       <td>0.234053</td>
#       <td>0.589168</td>
#       <td>0.485822</td>
#       <td>0.868243</td>
#       <td>0.532753</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.232064</td>
#       <td>0.212448</td>
#       <td>0.591810</td>
#       <td>0.474480</td>
#       <td>0.890071</td>
#       <td>0.523353</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.221401</td>
#       <td>0.197212</td>
#       <td>0.589168</td>
#       <td>0.449905</td>
#       <td>0.922481</td>
#       <td>0.501264</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.222695</td>
#       <td>0.191387</td>
#       <td>0.688243</td>
#       <td>0.616257</td>
#       <td>0.908078</td>
#       <td>0.658586</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0

# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='96' class='' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.79% [96/189 00:04<00:04 0.3116]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# Based on the range test, further train the model using a learning rate of 10E-4.

# %%
fit_recall_optimised(learner, n_epochs=10, max_learning_rate=1e-04, model_filename='vgg_temp')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.200363</td>
#       <td>0.165081</td>
#       <td>0.738441</td>
#       <td>0.672968</td>
#       <td>0.934383</td>
#       <td>0.712855</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.198407</td>
#       <td>0.169036</td>
#       <td>0.759577</td>
#       <td>0.722117</td>
#       <td>0.916067</td>
#       <td>0.754046</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.204250</td>
#       <td>0.179825</td>
#       <td>0.618230</td>
#       <td>0.483932</td>
#       <td>0.941176</td>
#       <td>0.536013</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.203854</td>
#       <td>0.168900</td>
#       <td>0.795244</td>
#       <td>0.776938</td>
#       <td>0.917411</td>
#       <td>0.801482</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.206491</td>
#       <td>0.157132</td>
#       <td>0.782034</td>
#       <td>0.750473</td>
#       <td>0.923256</td>
#       <td>0.779654</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.201747</td>
#       <td>0.167089</td>
#       <td>0.834875</td>
#       <td>0.852552</td>
#       <td>0.905622</td>
#       <td>0.862663</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.196695</td>
#       <td>0.167696</td>
#       <td>0.792602</td>
#       <td>0.784499</td>
#       <td>0.906114</td>
#       <td>0.806138</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.199938</td>
#       <td>0.164777</td>
#       <td>0.793923</td>
#       <td>0.775047</td>
#       <td>0.917226</td>
#       <td>0.799844</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.193960</td>
#       <td>0.162929</td>
#       <td>0.791281</td>
#       <td>0.767486</td>
#       <td>0.920635</td>
#       <td>0.793899</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.201919</td>
#       <td>0.163230</td>
#       <td>0.779392</td>
#       <td>0.750473</td>
#       <td>0.918981</td>
#       <td>0.779042</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with recall value: 0.6729678511619568.
# Better model found at epoch 1 with recall value: 0.7221171855926514.
# Better model found at epoch 3 with recall value: 0.7769376039505005.
# Better model found at epoch 5 with recall value: 0.8525519967079163.

# %% [markdown]
# ### Retrain from recall-optimiated model (VGG13)
#
# Load the best recall-optimised model, freeze and re-train.

# %%
learner.load('vgg_temp')
learner.freeze()
find_learning_rate(learner)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='97' class='' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       51.32% [97/189 00:04<00:03 0.2412]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
fit_recall_optimised(learner, n_epochs=10, max_learning_rate=7e-04, model_filename='vgg_temp')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.201787</td>
#       <td>0.160372</td>
#       <td>0.793923</td>
#       <td>0.767486</td>
#       <td>0.924829</td>
#       <td>0.794521</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.191244</td>
#       <td>0.159121</td>
#       <td>0.805812</td>
#       <td>0.792060</td>
#       <td>0.918860</td>
#       <td>0.814541</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.197916</td>
#       <td>0.155763</td>
#       <td>0.793923</td>
#       <td>0.758034</td>
#       <td>0.934732</td>
#       <td>0.787819</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.194452</td>
#       <td>0.159198</td>
#       <td>0.813738</td>
#       <td>0.807183</td>
#       <td>0.916309</td>
#       <td>0.826878</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0
td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.194892</td>
#       <td>0.158665</td>
#       <td>0.817701</td>
#       <td>0.814745</td>
#       <td>0.915074</td>
#       <td>0.833011</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.194818</td>
#       <td>0.156862</td>
#       <td>0.819022</td>
#       <td>0.812854</td>
#       <td>0.918803</td>
#       <td>0.832043</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with recall value: 0.8090737462043762.
# Better model found at epoch 3 with recall value: 0.8355387449264526.
# Better model found at epoch 5 with recall value: 0.8525519967079163.

# %%
learner.export(str(Path('vgg13_cement_binary_final.pkl')))
results['vgg'] = get_statistics(learner)
results['vgg']
# Out:
# {'Accuracy': 0.8361955,
#  'Recall': 0.852552,
#  'Precision': 0.90744466,
#  'Fbeta': 0.8629927}

# %% [markdown]
# ## Run 3 - Densenet161

# %% [markdown]
# ### Define Learner (Densenet161)
#
# Adapt Densenet161 using a weighted cross entropy as a custom loss function and using mixup to train the model. In addition, we will optimise models for recall, by selecting among training epochs.

# %%
learner = cnn_learner(data, 
                      models.densenet161,
                      # transfer learning on
                      pretrained=True,
                      # loss_func = LabelSmoothingCrossEntropy(), 
                      # class weighted cross entropy loss
                      loss_func=loss_w,
                      metrics=metrics_all,
                      opt_func=optim.Adam,
                      # batch norm at the end of the CNN
                      bn_final=True,
                      # nice callback for plotting loss for training and 
                      # validation during fitting 
                      # followed by mixup
                      callback_fns=ShowGraph).mixup()
# Out:
# Downloading: "https://download.pytorch.org/models/densenet161-8d451a50.pth" to /home/jovyan/.cache/torch/hub/checkpoints/densenet161-8d451a50.pth
# HBox(children=(FloatProgress(value=0.0, max=115730790.0), HTML(value='')))

# %% [markdown]
# ### Tune Learning Rate (Densenet161)
#
# Tune the learning rate based on Smith's (2015) range test.

# %%
find_learning_rate(learner)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.38% [99/189 00:19<00:17 0.3165]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# Based on the range test, a learning rate of 1E-02 appears to be reasonable, owing to the magnitude and slope of the associated loss.

# %%
fit_recall_optimised(learner, n_epochs=25, max_learning_rate=1e-02, model_filename='densenet_temp')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.267035</td>
#       <td>0.224295</td>
#       <td>0.669749</td>
#       <td>0.601134</td>
#       <td>0.890756</td>
#       <td>0.720274</td>
#       <td>0.642944</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.246888</td>
#       <td>0.221716</td>
#       <td>0.656539</td>
#       <td>0.586011</td>
#       <td>0.883191</td>
#       <td>0.709408</td>
#       <td>0.628294</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.239438</td>
#       <td>0.197672</td>
#       <td>0.602378</td>
#       <td>0.465028</td>
#       <td>0.931818</td>
#       <td>0.747331</td>
#       <td>0.516807</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.227212</td>
#       <td>0.189775</td>
#       <td>0.708058</td>
#       <td>0.642722</td>
#       <td>0.913979</td>
#       <td>0.755590</td>
#       <td>0.683280</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.225556</td>
#       <td>0.190658</td>
#       <td>0.626156</td>
#       <td>0.508507</td>
#       <td>0.921233</td>
#       <td>0.744372</td>
#       <td>0.558555</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.219694</td>
#       <td>0.181027</td>
#       <td>0.734478</td>
#       <td>0.688091</td>
#       <td>0.910000</td>
#       <td>0.756501</td>
#       <td>0.723370</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0
td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with recall value: 0.6011342406272888.
# Better model found at epoch 3 with recall value: 0.6427221298217773.
# Better model found at epoch 5 with recall value: 0.6880907416343689.
# Better model found at epoch 6 with recall value: 0.703213632106781.
# Better model found at epoch 12 with recall value: 0.706994354724884.
# Better model found at epoch 14 with recall value: 0.8015123009681702.

# %% [markdown]
# ### Retrain Densenet161 with lower learning rate
#
# Fine tune the entire model. We perform this by unfreezing the model, then repeating the learning rate range test.

# %%
# load the model with the best recall
learner.load('densenet_temp')
learner.unfreeze()
find_learning_rate(learner)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.38% [99/189 00:21<00:19 0.2873]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# Based on the range test, further train the model using a learning rate of 10E-4.

# %%
fit_recall_optimised(learner, n_epochs=10, max_learning_rate=1e-04, model_filename='densenet_temp')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.202538</td>
#       <td>0.166722</td>
#       <td>0.785997</td>
#       <td>0.754253</td>
#       <td>0.925754</td>
#       <td>0.791599</td>
#       <td>0.783274</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.212016</td>
#       <td>0.164957</td>
#       <td>0.745046</td>
#       <td>0.680529</td>
#       <td>0.937500</td>
#       <td>0.793774</td>
#       <td>0.720000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.208712</td>
#       <td>0.170679</td>
#       <td>0.737120</td>
#       <td>0.672968</td>
#       <td>0.931937</td>
#       <td>0.784771</td>
#       <td>0.712570</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.199813</td>
#       <td>0.169111</td>
#       <td>0.743725</td>
#       <td>0.674858</td>
#       <td>0.941953</td>
#       <td>0.798450</td>
#       <td>0.715431</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.207751</td>
#       <td>0.168483</td>
#       <td>0.780713</td>
#       <td>0.744802</td>
#       <td>0.927059</td>
#       <td>0.791801</td>
#       <td>0.775285</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.204203</td>
#       <td>0.170683</td>
#       <td>0.754293</td>
#       <td>0.691871</td>
#       <td>0.940874</td>
#       <td>0.800781</td>
#       <td>0.730539</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.199924</td>
#       <td>0.165514</td>
#       <td>0.807133</td>
#       <td>0.776938</td>
#       <td>0.936219</td>
#       <td>0.813008</td>
#       <td>0.804305</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.197643</td>
#       <td>0.164221</td>
#       <td>0.747688</td>
#       <td>0.680529</td>
#       <td>0.942408</td>
#       <td>0.800311</td>
#       <td>0.720576</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.190530</td>
#       <td>0.163683</td>
#       <td>0.789960</td>
#       <td>0.739130</td>
#       <td>0.949029</td>
#       <td>0.823389</td>
#       <td>0.773339</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.189358</td>
#       <td>0.160078</td>
#       <td>0.770145</td>
#       <td>0.714556</td>
#       <td>0.942643</td>
#       <td>0.808360</td>
#       <td>0.750894</td>
#       <td>00:41</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with recall value: 0.7542533278465271.
# Better model found at epoch 6 with recall value: 0.7769376039505005.

# %% [markdown]
# ### Retrain recall-optimized model (Densenet161)
#
# Load the best recall-optimised model, freeze and re-train.

# %%
learner.load('densenet_temp')
learner.freeze()
find_learning_rate(learner)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='189' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       52.38% [99/189 00:17<00:16 0.2534]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
fit_recall_optimised(learner, n_epochs=10, max_learning_rate=7e-04, model_filename='densenet_temp')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall</th>
#       <th>precision</th>
#       <th>f_beta</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0
td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.194710</td>
#       <td>0.158686</td>
#       <td>0.767503</td>
#       <td>0.712665</td>
#       <td>0.940150</td>
#       <td>0.804416</td>
#       <td>0.748907</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.184133</td>
#       <td>0.157645</td>
#       <td>0.792602</td>
#       <td>0.750473</td>
#       <td>0.940758</td>
#       <td>0.813953</td>
#       <td>0.782112</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.191271</td>
#       <td>0.161283</td>
#       <td>0.768824</td>
#       <td>0.714556</td>
#       <td>0.940298</td>
#       <td>0.805051</td>
#       <td>0.750596</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.188808</td>
#       <td>0.160531</td>
#       <td>0.804491</td>
#       <td>0.771267</td>
#       <td>0.937931</td>
#       <td>0.814425</td>
#       <td>0.799686</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.187280</td>
#       <td>0.159267</td>
#       <td>0.799207</td>
#       <td>0.761815</td>
#       <td>0.939394</td>
#       <td>0.814516</td>
#       <td>0.791749</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.188899</td>
#       <td>0.160064</td>
#       <td>0.785997</td>
#       <td>0.739130</td>
#       <td>0.942169</td>
#       <td>0.813397</td>
#       <td>0.772422</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.182917</td>
#       <td>0.158627</td>
#       <td>0.780713</td>
#       <td>0.731569</td>
#       <td>0.941606</td>
#       <td>0.810811</td>
#       <td>0.765730</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.193973</td>
#       <td>0.158340</td>
#       <td>0.778071</td>
#       <td>0.727788</td>
#       <td>0.941320</td>
#       <td>0.809524</td>
#       <td>0.762376</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.195271</td>
#       <td>0.160082</td>
#       <td>0.793923</td>
#       <td>0.756144</td>
#       <td>0.936768</td>
#       <td>0.809179</td>
#       <td>0.786473</td>
#       <td>00:41</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with recall value: 0.7107750177383423.
# Better model found at epoch 1 with recall value: 0.7221171855926514.
# Better model found at epoch 4 with recall value: 0.735349714756012.
# Better model found at epoch 5 with recall value: 0.7542533278465271.
# Better model found at epoch 9 with recall value: 0.771266520023346.

# %%
learner.export(str(Path('densenet161_cement_binary_final.pkl')))
results['densenet'] = get_statistics(learner)
results['densenet']
# Out:
# {'Accuracy': 0.8044914,
#  'Recall': 0.7712665,
#  'Precision': 0.93793106,
#  'Fbeta': 0.81442463}

# %% [markdown]
# ## Obtain Summary of Results Across Models

# %%
pd.DataFrame(results)
# Out:
#                 vgg  densenet
# Accuracy   0.836196  0.804491
# Recall     0.852552  0.771267
# Precision  0.907445  0.937931
# Fbeta      0.862993  0.814425

# %% [markdown]
# Based on obtained results, we select Resnet as the best-performing model

# %% [markdown]
# ## Analyze Results Obtained Using VGG

# %%
ClassConfusion(interpretations['vgg'], classlist=['cement','landcover'], is_ordered=False, figsize=(8,8))
# Out:
# Please enter a value for `k`, or the top images you will see:  10
# 100%|██████████| 2/2 [00:01<00:00,  1.80it/s]
# Tab(children=(Output(), Output()), _titles={'0': 'landcover | cement', '1': 'cement | landcover'})

# %% [markdown]
# List of largest non-diagonal entries in the confusion matrix (actual | predicted | number of occurences).

# %%
interpretations['vgg'].most_confused()
# Out:
# [('landcover', 'cement', 78), ('cement', 'landcover', 46)]

# %% [markdown]
# ## Upload models to S3

# %%
model_results = glob.glob(IMG_DIR+'/*.pkl')

# %%
for m in model_results:
    bucket.upload_file(m, AWS_SOURCE_PATH+'/'+AWS_MODEL_PATH+'/'+m.split('/')[-1])
