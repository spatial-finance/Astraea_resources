# %%
import os
import geopandas as gpd
import pandas as pd
import fiona
from earthai.geo import reproject_on_the_fly
import statistics
import matplotlib.pyplot as plt
from datetime import date
import re

# %%
# Enable fiona driver
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'

# %%
# read in annotations
df_annotations = pd.DataFrame()

for path, subdirs, files in os.walk('Completed'):
    for name in files:
        if name.endswith(".kml"): 
            full_path = os.path.join(path, name)
            name = full_path.split("/")[-2]
            plant = full_path.split("/")[-1]
            
            # Read file
            tmp = gpd.read_file(full_path, driver='KML')               
            tmp['Processed By'] = name.strip()
            tmp['tile_id'] = plant.split(".")[0].strip()

            df_annotations = df_annotations.append(tmp, ignore_index=True)
            
for path, subdirs, files in os.walk('Astraea to Review'):
    for name in files:
        if name.endswith(".kml"): 
            full_path = os.path.join(path, name)
            name = full_path.split("/")[-2]
            plant = full_path.split("/")[-1]
            
            # Read file
            tmp = gpd.read_file(full_path, driver='KML')               
            tmp['Processed By'] = name.strip()
            tmp['tile_id'] = plant.split(".")[0].strip()

            df_annotations = df_annotations.append(tmp, ignore_index=True)

# %%
# read in statuses
df_status = pd.DataFrame()

sets=['Annotation Tab']
for s in sets:
    tmp = pd.read_excel("Steel Plant Localization - Group One Worksheet.xlsx", sheet_name=s)
    tmp = tmp[['tile_id','plant_found','class', 'level','imagery_date','Processed By','status']]
    
    df_status = df_status.append(tmp, ignore_index=True)
    
# convert to string
df_status['Processed By'] = df_status['Processed By'].astype(str)
df_status['tile_id'] = df_status['tile_id'].astype(str)

# to lower case
df_status['Processed By'] = df_status['Processed By'].str.lower()

# remove any leading/trailing spaces
df_status['tile_id'] = df_status['tile_id'].str.strip()
df_status['Processed By'] = df_status['Processed By'].str.strip()

# fix status
df_status.status = df_status.status.fillna('')
df_status.status = df_status.status.str.lower()
df_status.status = df_status.status.str.strip()

# fix status
df_status.plant_found = df_status.plant_found.fillna('')
df_status.plant_found = df_status.plant_found.str.lower()
df_status.plant_found = df_status.plant_found.str.strip()

# %%
# # check if merge worked
df = pd.merge(df_status, df_annotations, how='outer', left_on=['tile_id', 'Processed By'], right_on=['tile_id', 'Processed By'], indicator=True)

# df._merge.value_counts()
# df[df._merge == 'both']['Processed By'].value_counts()
# df[df._merge == 'right_only']['Processed By'].value_counts()
# df[df._merge == 'left_only']['Processed By'].value_counts()

# %%
df[df._merge == 'both']['Processed By'].value_counts()
# Out:
# maina lawrence irungu        105
# fiona atieno                  81
# john oduor otieno             63
# joshua gichuki mwangi         50
# rasoa simiyu                  29
# moses njau                    29
# isaack odhiambo otieno        23
# emily nyawira waithera        22
# marvin mwangi                 18
# benice wairimu ruga           17
# caroline kioko                16
# vincent kipngetich            14
# clement omunga                 9
# mwangi emmanuel                8
# eva irungu                     6
# damaris kwamboka okenyuri      4
# ephantus maina                 4
# Name: Processed By, dtype: int64

# %%
df[df._merge == 'right_only']['Processed By'].value_counts()
# Out:
# eva irungu    9
# Name: Processed By, dtype: int64

# %%
df[df._merge == 'left_only']['Processed By'].value_counts()
# Out:
# benice wairimu ruga          655
# marvin mwangi                578
# rasoa simiyu                 558
# caroline kioko               471
# isaack odhiambo otieno       456
# john oduor otieno            450
# joshua gichuki mwangi        442
# maina lawrence irungu        404
# vincent kipngetich           403
# clement omunga               379
# fiona atieno                 344
# ephantus maina               269
# eva irungu                   239
# damaris kwamboka okenyuri    224
# erick karanja                181
# moses njau                   172
# njoki muriithi               154
# emily nyawira waithera       153
# mwangi emmanuel               89
# Name: Processed By, dtype: int64

# %%
df_status_count = df_status.status.value_counts().reset_index()
df_status_count.columns = ['status', 'count']
df_status_count['percent'] = (df_status_count['count'] / df_status_count['count'].sum())*100
df_status_count
# Out:
#                 status  count    percent
# 0            no issues   6489  92.356960
# 1           no imagery    410   5.835468
# 2      unclear imagery     72   1.024765
# 3  plant already found     39   0.555081
# 4       cloudy imagery      9   0.128096
# 5      duplicate plant      7   0.099630

# %%
# join annotations and statuses
df = pd.merge(df_status, df_annotations, how='left', left_on=['tile_id', 'Processed By'], right_on=['tile_id', 'Processed By'])

# drop duplicates in case annotator accidentally exported the same annotation twice
df = df.drop_duplicates()

# %%
df['Acquisition_Date'] = pd.to_datetime(df.Description, errors='coerce')
df['Acquisition_Year'] = df['Acquisition_Date'].dt.year

df['Acquisition_Date2'] = pd.to_datetime(df.imagery_date, errors='coerce')
df['Acquisition_Year2'] = df['Acquisition_Date2'].dt.year

# %%
df_year_count = df.Acquisition_Year.value_counts().reset_index()
df_year_count.columns = ['year', 'count']
df_year_count['percent'] = (df_year_count['count'] / df_year_count['count'].sum())*100
df_year_count['year'] = df_year_count['year'].astype(int)
df_year_count = df_year_count[(df_year_count.year != 2026) & (df_year_count.year != 2107)]
df_year_count.sort_values('year')
# Out:
#     year  count    percent
# 5   2004      7   1.405622
# 11  2010      1   0.200803
# 10  2011      2   0.401606
# 9   2012      3   0.602410
# 8   2013      3   0.602410
# 4   2014     11   2.208835
# 7   2015      3   0.602410
# 6   2016      5   1.004016
# 3   2017     19   3.815261
# 2   2018     43   8.634538
# 1   2019    137  27.510040
# 0   2020    263  52.811245
# 12  2021      1   0.200803

# %% [markdown]
# ### Quality Assurance

# %%
def check_annotation_quality(group):
    # add geometry type (point, linestring, polygon)
    group['geom_type'] = group.geometry.apply(lambda x: x.type)
    
    s = ""
    
    # check if point is missing
    if len(group[group.geom_type == 'Point']) == 0:
        s += "Point is missing; "
            
    # check acquisition dates
    for idx, row in group.iterrows():
        if pd.notnull(row.Acquisition_Date):
            if row.Acquisition_Date.year < 1900 or row.Acquisition_Date.year > 2021:
                s += "Date format is incorrect on one of annotations; "
        else:
            s += "Date is missing for annotated point; "
    
        if row.Name.strip() == '':
            s += "Name is missing for annotated point; "
            
    return s

# %%
# Remove previous feedback
# !rm -r Completed/*
# !rm -r CloudFactory\ to\ Review/*
# !rm Completed.tar.gz
# !rm CloudFactory\ to\ Review.tar.gz

# %%
# check if we have all the annotations
grouped = df.groupby(['tile_id'])
results_df = pd.DataFrame(columns=['tile_id', 'annotator1', 'issues1'])

for name, group in grouped:
    
    res_dict = {}
    res_dict['tile_id'] = name    
    
    grouped2 = group.groupby(['tile_id', 'Processed By', 'status', 'plant_found', 'class', 'level', 'Acquisition_Date2', 'Acquisition_Year2'])
    idx = 1
    for name2, group2 in grouped2:
        s = ""
        if name2[2].strip() == '':
            s = "Status is missing; "
        elif name2[3].strip() == '':
            s = "Plant_found is missing; "
        elif name2[2] == 'no issues' and name2[3] == 'yes':
            if len(group2[group2.Name.notnull()]) == 0:
                s = "Annotations are missing; "
            else:
                s = check_annotation_quality(group2)
        
        if name2[4].strip() == '':
            s += "Class is missing; "
        if name2[5].strip() == '':
            s += "Level is missing; "
        if pd.isnull(name2[6]):
            s += "imagery_date is missing or format is incorrect; "
        else:
            if name2[7] < 1900 or name2[7] > 2021:
                s += "imagery_date format is incorrect; "

            
        res_dict['annotator{}'.format(idx)] = name2[1] 
        res_dict['issues{}'.format(idx)] = s 
        idx += 1
        
        tmp = df_annotations[(df_annotations["Processed By"] == name2[1]) & (df_annotations.tile_id == name)]
        
        if name2[1] != 'nan':
            if not os.path.isdir('Completed/{}'.format(name2[1])):
                os.mkdir('Completed/{}'.format(name2[1])) 
                os.mkdir('CloudFactory to Review/{}'.format(name2[1])) 

            if len(tmp) > 0:
                if s == '':
                    with fiona.drivers():
                        tmp.to_file('Completed/{}/{}.kml'.format(name2[1], name), driver='KML')
                else:
                    with fiona.drivers():
                        tmp.to_file('CloudFactory to Review/{}/{}.kml'.format(name2[1], name), driver='KML')
                        
    results_df = results_df.append(res_dict, ignore_index=True)

# %%
def check_overall(row):
    num_issues = 0
    if row.issues1 != '':
        num_issues += 1
    return 1 - num_issues

results_df['num_completed'] = results_df.apply(check_overall,axis=1)

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/conda/envs/earthai/lib/python3.7/site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in /opt/conda/envs/earthai/lib/python3.7/site-packages (from openpyxl) (1.0.1)

# %%
results_df.to_csv('feedback.csv', index=False)

# %%
# import openpyxl as pxl

# excel_book = pxl.load_workbook("Steel Plant Localization - Group One Worksheet.xlsx")
# with pd.ExcelWriter("Steel Plant Localization - Group One Worksheet.xlsx", engine='openpyxl') as writer:
#     writer.book = excel_book
#     writer.sheets = {
#         worksheet.title: worksheet
#         for worksheet in excel_book.worksheets
#     }
#     results_df.to_excel(writer, 'Feedback', index=False)
#     writer.save()

# %% [markdown]
# ### TODO: Go back and fix above labels.

# %%
# !tar -czvf "CloudFactory to Review.tar.gz" "CloudFactory to Review/"
# !tar -czvf Completed.tar.gz Completed/
# Out:
# CloudFactory to Review/
# CloudFactory to Review/marvin mwangi/
# CloudFactory to Review/emily nyawira waithera/
# CloudFactory to Review/damaris kwamboka okenyuri/
# CloudFactory to Review/caroline kioko/
# CloudFactory to Review/rasoa simiyu/
# CloudFactory to Review/eva irungu/
# CloudFactory to Review/njoki muriithi/
# CloudFactory to Review/erick karanja/
# CloudFactory to Review/john oduor otieno/
# CloudFactory to Review/ephantus maina/
# CloudFactory to Review/joshua gichuki mwangi/
# CloudFactory to Review/maina lawrence irungu/
# CloudFactory to Review/moses njau/
# CloudFactory to Review/fiona atieno/
# CloudFactory to Review/vincent kipngetich/
# CloudFactory to Review/isaack odhiambo otieno/
# CloudFactory to Review/benice wairimu ruga/
# CloudFactory to Review/mwangi emmanuel/
# CloudFactory to Review/clement omunga/
# Completed/
# Completed/marvin mwangi/
# Completed/marvin mwangi/MGRS-50TQL-0266-2020-01.kml
# Completed/marvin mwangi/MGRS-48RUS-0059-2020-01.kml
# Completed/marvin mwangi/MGRS-49TCF-0402-2020-01.kml
# Completed/marvin mwangi/MGRS-49REL-0231-2020-01.kml
# Completed/marvin mwangi/MGRS-49QGF-0452-2020-01.kml
# Completed/marvin mwangi/MGRS-45TVK-0112-2020-01.kml
# Completed/marvin mwangi/MGRS-48RUT-0245-2020-01.kml
# Completed/marvin mwangi/MGRS-49SGS-0086-2020-03.kml
# Completed/marvin mwangi/MGRS-50SME-0623-2020-01.kml
# Completed/marvin mwangi/MGRS-50SNH-0403-2020-01.kml
# Completed/marvin mwangi/MGRS-49SEV-0590-2020-01.kml
# Completed/marvin mwangi/MGRS-47RRH-0259-2020-01.kml
# Completed/marvin mwangi/MGRS-49SFB-0012-2020-09.kml
# Completed/marvin mwangi/MGRS-49SGC-0197-2020-01.kml
# Completed/emily nyawira waithera/
# Completed/emily nyawira waithera/MGRS-49SGA-0272-2020-02.kml
# Completed/emily nyawira waithera/MGRS-50SNF-0350-2020-01.kml
# Completed/emily nyawira waithera/MGRS-51TVF-0370-2020-01.kml
# Completed/emily nyawira waithera/MGRS-49SGA-0698-2020-02.kml
# Completed/emily nyawira waithera/MGRS-51TVF-0361-2020-01.kml
# Completed/emily nyawira waithera/MGRS-50SKF-0931-2020-03.kml
# Completed/emily nyawira waithera/MGRS-51TVF-0684-2020-01.kml
# Completed/emily nyawira waithera/MGRS-51TVF-0332-2020-01.kml
# Completed/emily nyawira waithera/MGRS-49SGA-0292-2020-02.kml
# Completed/emily nyawira waithera/MGRS-50TQR-0279-2020-05.kml
# Completed/emily nyawira waithera/MGRS-50SKF-0288-2020-03.kml
# Completed/emily nyawira waithera/MGRS-51TVF-0429-2020-01.kml
# Completed/emily nyawira waithera/MGRS-51TVF-0371-2020-01.kml
# Completed/emily nyawira waithera/MGRS-50SKF-0411-2020-03.kml
# Completed/emily nyawira waithera/MGRS-49SGA-0697-2020-02.kml
# Completed/emily nyawira waithera/MGRS-50SKF-0462-2020-03.kml
# Completed/emily nyawira waithera/MGRS-50SKF-0358-2020-03.kml
# Completed/emily nyawira waithera/MGRS-45TWJ-0328-2020-01.kml
# Completed/damaris kwamboka okenyuri/
# Completed/damaris kwamboka okenyuri/MGRS-48RXT-0033-2020-01.kml
# Completed/fiona atieno/MGRS-49TFE-0056-2020-03.kml
# Completed/fiona atieno/MGRS-52TCM-0068-2020-01.kml
# Completed/fiona atieno/MGRS-53TLN-0342-2020-01.kml
# Completed/fiona atieno/MGRS-50TPK-0416-2020-01.kml
# Completed/fiona atieno/MGRS-52TDN-0011-2020-01.kml
# Completed/fiona atieno/MGRS-51TWF-0357-2020-02.kml
# Completed/fiona atieno/MGRS-52TCR-0106-2020-01.kml
# Completed/fiona atieno/MGRS-50SQB-0282-2020-01.kml
# Completed/fiona atieno/MGRS-52TBL-0136-2020-05.kml
# Completed/fiona atieno/MGRS-49SEV-0444-2020-01.kml
# Completed/fiona atieno/MGRS-50SQD-0046-2020-01.kml
# Completed/fiona atieno/MGRS-50TPM-0217-2020-08.kml
# Completed/fiona atieno/MGRS-52TCR-0313-2020-01.kml
# Completed/fiona atieno/MGRS-49SCA-0473-2020-02.kml
# Completed/fiona atieno/MGRS-50SPJ-0348-2020-03.kml
# Completed/fiona atieno/MGRS-51TWF-0128-2020-02.kml
# Completed/fiona atieno/MGRS-45TVK-0058-2020-01.kml
# Completed/fiona atieno/MGRS-52TCM-0754-2020-01.kml
# Completed/fiona atieno/MGRS-50SPJ-0313-2020-03.kml
# Completed/fiona atieno/MGRS-48SWD-0386-2020-01.kml
# Completed/fiona atieno/MGRS-52TCR-0038-2020-01.kml
# Completed/vincent kipngetich/
# Completed/vincent kipngetich/MGRS-45TVJ-0241-2020-01.kml
# Completed/vincent kipngetich/MGRS-52TDT-0132-2020-08.kml
# Completed/vincent kipngetich/MGRS-49QDE-0052-2020-01.kml
# Completed/vincent kipngetich/MGRS-51TWK-0396-2020-01.kml
# Completed/vincent kipngetich/MGRS-52UGU-0024-2020-01.kml
# Completed/vincent kipngetich/MGRS-48SWH-0196-2020-01.kml
# Completed/vincent kipngetich/MGRS-49SCA-0472-2020-02.kml
# Completed/vincent kipngetich/MGRS-49TCE-0031-2020-01.kml
# Completed/vincent kipngetich/MGRS-46SFF-0031-2020-01.kml
# Completed/vincent kipngetich/MGRS-44TMN-0068-2020-01.kml
# Completed/vincent kipngetich/MGRS-49QDE-0260-2020-01.kml
# Completed/vincent kipngetich/MGRS-45TXH-0301-2020-12.kml
# Completed/vincent kipngetich/MGRS-51UXQ-0052-2020-01.kml
# Completed/vincent kipngetich/MGRS-51UXQ-0007-2020-01.kml
# Completed/isaack odhiambo otieno/
# Completed/isaack odhiambo otieno/MGRS-52UDV-0105-2020-01.kml
# Completed/isaack odhiambo otieno/MGRS-52UDV-0033-2020-01.kml
# Completed/isaack odhiambo otieno/MGRS-48RTN-0301-2020-01.kml
# Completed/isaack odhiambo otieno/MGRS-48RXU-0900-2020-01.kml
# Completed/isaack odhiambo otieno/MGRS-51UYQ-0096-2020-01.kml
# Completed/isaack odhiambo otieno/MGRS-50SNJ-0554-2020-03.kml
# Completed/isaack odhiambo otieno/MGRS-50SNJ-0473-2020-03.kml
# Completed/isaack odhiambo otieno/MGRS-50SNJ-0967-2020-03.kml
# Completed/isaack odhiambo otieno/MGRS-52UCV-0223-2020-03.kml
# Completed/isaack odhiambo otieno/MGRS-52TGR-0207-2020-02.kml
# Completed/isaack odhiambo otieno/MGRS-50SNJ-0947-2020-03.kml
# Completed/isaack odhiambo otieno/MGRS-50SNJ-0772-2020-03.kml
# Completed/isaack odhiambo otieno/MGRS-52UCV-0236-2020-03.kml
# Completed/isaack odhiambo otieno/MGRS-50SNJ-0503-2020-03.kml
# Completed/isaack odhiambo otieno/MGRS-52UDV-0022-2020-01.kml
# Completed/isaack odhiambo otieno/MGRS-52UDV-0103-2020-01.kml
# Completed/isaack odhiambo otieno/MGRS-49QGE-0748-2020-01.kml
# Completed/isaack odhiambo otieno/MGRS-52UCV-0141-2020-03.kml
# Completed/isaack odhiambo otieno/MGRS-50SNJ-0797-2020-03.kml
# Completed/isaack odhiambo otieno/MGRS-52UDV-0108-2020-01.kml
# Completed/benice wairimu ruga/
# Completed/benice wairimu ruga/MGRS-50TQK-0151-2020-01.kml
# Completed/benice wairimu ruga/MGRS-49SEV-0311-2020-01.kml
# Completed/benice wairimu ruga/MGRS-51TVE-0065-2020-01.kml
# Completed/benice wairimu ruga/MGRS-48QZK-0536-2020-01.kml
# Completed/benice wairimu ruga/MGRS-52TCM-0041-2020-01.kml
# Completed/benice wairimu ruga/MGRS-49SGA-0672-2020-02.kml
# Completed/benice wairimu ruga/MGRS-49SEC-0268-2020-01.kml
# Completed/benice wairimu ruga/MGRS-50TNK-0641-2020-02.kml
# Completed/benice wairimu ruga/MGRS-50SKG-0822-2020-01.kml
# Completed/benice wairimu ruga/MGRS-49QBE-0567-2020-04.kml
# Completed/benice wairimu ruga/MGRS-50SNE-0019-2020-01.kml
# Completed/benice wairimu ruga/MGRS-51TVE-0013-2020-01.kml
# Completed/benice wairimu ruga/MGRS-50TNK-0723-2020-02.kml
# Completed/benice wairimu ruga/MGRS-49SEA-0519-2020-03.kml
# Completed/mwangi emmanuel/
# Completed/mwangi emmanuel/MGRS-51STU-0048-2020-01.kml
# Completed/mwangi emmanuel/MGRS-47RQK-0247-2020-01.kml
# Completed/mwangi emmanuel/MGRS-49SGS-0086-2020-03.kml
# Completed/mwangi emmanuel/MGRS-51STU-0043-2020-01.kml
# Completed/mwangi emmanuel/MGRS-49SGS-0087-2020-03.kml
# Completed/clement omunga/
# Completed/clement omunga/MGRS-50SNH-0374-2020-01.kml
# Completed/clement omunga/MGRS-50SNH-0176-2020-01.kml
# Completed/clement omunga/MGRS-52TCP-0098-2020-02.kml
# Completed/clement omunga/MGRS-51STV-0194-2020-02.kml
# Completed/clement omunga/MGRS-50SNH-0004-2020-01.kml
# Completed/clement omunga/MGRS-50RQT-0782-2020-01.kml
# Completed/clement omunga/MGRS-50SNH-0753-2020-01.kml
# Completed/clement omunga/MGRS-50SNH-0003-2020-01.kml
# Completed/clement omunga/MGRS-50SNH-0399-2020-01.kml
