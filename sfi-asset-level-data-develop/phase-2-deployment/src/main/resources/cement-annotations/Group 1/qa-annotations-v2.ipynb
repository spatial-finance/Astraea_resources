# %%
import os
import geopandas as gpd
import pandas as pd
import fiona
from earthai.geo import reproject_on_the_fly
import statistics
import matplotlib.pyplot as plt
from datetime import date
import re

# %%
# Enable fiona driver
gpd.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw'

# %%
# read in annotations
df_annotations = pd.DataFrame()

for path, subdirs, files in os.walk('Completed'):
    for name in files:
        if name.endswith(".kml"): 
            full_path = os.path.join(path, name)
            name = full_path.split("/")[-2]
            plant = full_path.split("/")[-1]
            
            # Read file
            tmp = gpd.read_file(full_path, driver='KML')               
            tmp['Processed By'] = name.strip()
            tmp['uid'] = plant.split(".")[0].strip()

            df_annotations = df_annotations.append(tmp, ignore_index=True)
            
for path, subdirs, files in os.walk('Astraea to Review'):
    for name in files:
        if name.endswith(".kml"): 
            full_path = os.path.join(path, name)
            name = full_path.split("/")[-2]
            plant = full_path.split("/")[-1]
            
            # Read file
            tmp = gpd.read_file(full_path, driver='KML')               
            tmp['Processed By'] = name.strip()
            tmp['uid'] = plant.split(".")[0].strip()

            df_annotations = df_annotations.append(tmp, ignore_index=True)

# %%
# function to remove middle name from excel spreadsheet
def remove_middle_name(name):
    arr = name.split()
    if len(arr) > 2:
        return arr[0] + ' ' + arr[2]
    elif len(arr) == 2:
        return arr[0] + ' ' + arr[1]
    else:
        return name

# %%
# read in statuses
df_status = pd.DataFrame()

sets=['Annotator 1', 'Annotator 2', 'Annotator 3']
for s in sets:
    tmp = pd.read_excel("Cement Plant Annotation Worksheet.xlsx", sheet_name=s)
    tmp = tmp[['uid','latitude','longitude','Date Processed','Processed By','status','notes']]
    
    df_status = df_status.append(tmp, ignore_index=True)
    
# convert to string
df_status['Processed By'] = df_status['Processed By'].astype(str)
df_status['uid'] = df_status['uid'].astype(str)

# remove middle name from 
df_status['Processed By'] = df_status['Processed By'].apply(remove_middle_name).str.lower()

# remove any leading/trailing spaces
df_status['uid'] = df_status['uid'].str.strip()
df_status['Processed By'] = df_status['Processed By'].str.strip()

# fix status
df_status.status = df_status.status.fillna('')
df_status.status = df_status.status.str.lower()

# %%
# # check if merge worked
df = pd.merge(df_status, df_annotations, how='outer', left_on=['uid', 'Processed By'], right_on=['uid', 'Processed By'], indicator=True)

# df._merge.value_counts()
# df[df._merge == 'both']['Processed By'].value_counts()
# df[df._merge == 'right_only']['Processed By'].value_counts()
# df[df._merge == 'left_only']['Processed By'].value_counts()

# %%
df[df._merge == 'both']['Processed By'].value_counts()
# Out:
# rasoa simiyu          385
# john otieno           313
# benice ruga           285
# isaack otieno         266
# moses njau            243
# vincent kipngetich    240
# marvin mwangi         216
# joshua mwangi         213
# damaris okenyuri      211
# maina irungu          174
# fiona atieno          173
# erick karanja         171
# caroline kioko        169
# regina nyambu         169
# solomon gachure       127
# emily waithera        119
# njoki muriithi        112
# clement omunga        104
# ephantus maina         89
# Name: Processed By, dtype: int64

# %%
df[df._merge == 'right_only']['Processed By'].value_counts()
# Out:
# isaack otieno         4
# vincent kipngetich    4
# marvin mwangi         4
# regina nyambu         1
# Name: Processed By, dtype: int64

# %%
df[df._merge == 'left_only']['Processed By'].value_counts()
# Out:
# benice ruga           4
# marvin mwangi         4
# njoki muriithi        3
# rasoa simiyu          2
# fiona atieno          2
# ephantus maina        2
# damaris okenyuri      1
# vincent kipngetich    1
# john otieno           1
# regina nyambu         1
# Name: Processed By, dtype: int64

# %%
df_status_count = df_status.status.value_counts().reset_index()
df_status_count.columns = ['status', 'count']
df_status_count['percent'] = (df_status_count['count'] / df_status_count['count'].sum())*100
df_status_count
# Out:
#                      status  count    percent
# 0                 no issues    777  88.395904
# 1        kiln under a cover     40   4.550626
# 2           unclear imagery     21   2.389078
# 3           kiln is blocked     20   2.275313
# 4  plant under construction     15   1.706485
# 5           plant not found      3   0.341297
# 6            cloudy imagery      2   0.227531
# 7                no imagery      1   0.113766

# %%
# join annotations and statuses
df = pd.merge(df_status, df_annotations, how='left', left_on=['uid', 'Processed By'], right_on=['uid', 'Processed By'])

# drop duplicates in case annotator accidentally exported the same annotation twice
df = df.drop_duplicates()

# %%
df['Acquisition_Date'] = pd.to_datetime(df.Description, errors='coerce')
df['Acquisition_Year'] = df['Acquisition_Date'].dt.year

# %%
df_year_count = df.Acquisition_Year.value_counts().reset_index()
df_year_count.columns = ['year', 'count']
df_year_count['percent'] = (df_year_count['count'] / df_year_count['count'].sum())*100
df_year_count['year'] = df_year_count['year'].astype(int)
df_year_count = df_year_count[(df_year_count.year != 2026) & (df_year_count.year != 2107)]
df_year_count.sort_values('year')
# Out:
#     year  count    percent
# 16  2002      6   0.164204
# 17  2003      3   0.082102
# 12  2004     41   1.122058
# 19  2005      2   0.054735
# 15  2006     11   0.301040
# 18  2007      2   0.054735
# 14  2008     11   0.301040
# 13  2009     27   0.738916
# 11  2010     58   1.587302
# 8   2011     75   2.052545
# 10  2012     67   1.833607
# 9   2013     72   1.970443
# 5   2014    111   3.037767
# 6   2015    105   2.873563
# 4   2016    274   7.498632
# 3   2017    459  12.561576
# 2   2018    593  16.228790
# 1   2019    711  19.458128
# 0   2020    942  25.779967
# 7   2021     83   2.271483

# %% [markdown]
# ### Quality Assurance

# %%
def check_annotation_quality(group):
    # add geometry type (point, linestring, polygon)
    group['geom_type'] = group.geometry.apply(lambda x: x.type)
    
    s = ""
    
    # check polygon if missing
    if len(group[group.geom_type == 'Polygon']) == 0:
        s += "Polygon is missing; "
    # check if multiple polygons
    elif len(group[group.geom_type == 'Polygon']) > 1:
        s += "Multiple polygons annotated; "
        
    # check number of linestrings for each kiln
    grouped2 = group[group.geom_type == 'LineString'].groupby(['uid', 'Processed By', 'Name'])
    for name2, group2 in grouped2:
        # check if missing measurement
        if len(group2) < 2:
            s += "Length or width of kiln {} is missing; ".format(name2[2])
        # check if too many measurements
        elif len(group2) > 2:
            s += "More than 2 line measurements for kiln {}; ".format(name2[2])
            
    return s

# %%
# Remove previous feedback
# !rm -r Completed/*
# !rm -r CloudFactory\ to\ Review/*
# !rm Completed.tar.gz
# !rm CloudFactory\ to\ Review.tar.gz
# Out:
# rm: cannot remove 'Completed.tar.gz': No such file or directory
# rm: cannot remove 'CloudFactory to Review.tar.gz': No such file or directory

# %%
# check if we have all the annotations
grouped = df.groupby(['uid'])
results_df = pd.DataFrame(columns=['uid', 'annotator1', 'issues1', 'annotator2', 'issues2', 'annotator3', 'issues3'])

for name, group in grouped:
    
    res_dict = {}
    res_dict['uid'] = name    
    
    grouped2 = group.groupby(['uid', 'Processed By', 'status'])
    idx = 1
    for name2, group2 in grouped2:
        if name2[2].strip() == '':
            s = "Status is missing"
        elif name2[2] == 'no issues':
            if len(group2[group2.Name.notnull()]) == 0:
                s = "Annotations are missing"
            else:
                s = check_annotation_quality(group2)
        else:
            s = ''
        res_dict['annotator{}'.format(idx)] = name2[1] 
        res_dict['issues{}'.format(idx)] = s 
        idx += 1
        
        tmp = df_annotations[(df_annotations["Processed By"] == name2[1]) & (df_annotations.uid == name)]
        
        if name2[1] != 'nan':
            if not os.path.isdir('Completed/{}'.format(name2[1])):
                os.mkdir('Completed/{}'.format(name2[1])) 
                os.mkdir('CloudFactory to Review/{}'.format(name2[1])) 

            if len(tmp) > 0:
                if s == '':
                    with fiona.drivers():
                        tmp.to_file('Completed/{}/{}.kml'.format(name2[1], name), driver='KML')
                else:
                    with fiona.drivers():
                        tmp.to_file('CloudFactory to Review/{}/{}.kml'.format(name2[1], name), driver='KML')
                
    results_df = results_df.append(res_dict, ignore_index=True)

# %%
def check_overall(row):
    num_issues = 0
    if row.issues1 != '':
        num_issues += 1
    if row.issues2 != '':
        num_issues += 1
    if row.issues3 != '':
        num_issues += 1
    return 3 - num_issues

results_df['num_completed'] = results_df.apply(check_overall,axis=1)

# %%
# with pd.option_context('display.max_rows', 300):
#     display(results_df)

today = date.today()
results_df.to_csv('feedback/quality_assurance_{}.csv'.format(today), index=False)

# %% [markdown]
# ### TODO: Go back and fix above labels.

# %%
# !tar -czvf "CloudFactory to Review.tar.gz" "CloudFactory to Review/"
# !tar -czvf Completed.tar.gz Completed/
# Out:
# CloudFactory to Review/
# CloudFactory to Review/maina irungu/
# CloudFactory to Review/marvin mwangi/
# CloudFactory to Review/regina nyambu/
# CloudFactory to Review/isaack otieno/
# CloudFactory to Review/caroline kioko/
# CloudFactory to Review/rasoa simiyu/
# CloudFactory to Review/solomon gachure/
# CloudFactory to Review/njoki muriithi/
# CloudFactory to Review/erick karanja/
# CloudFactory to Review/ephantus maina/
# CloudFactory to Review/emily waithera/
# CloudFactory to Review/benice ruga/
# CloudFactory to Review/moses njau/
# CloudFactory to Review/john otieno/
# CloudFactory to Review/fiona atieno/
# CloudFactory to Review/vincent kipngetich/
# CloudFactory to Review/joshua mwangi/
# CloudFactory to Review/damaris okenyuri/
# CloudFactory to Review/clement omunga/
# Completed/
# Completed/maina irungu/
# Completed/maina irungu/EGY0009.kml
# Completed/maina irungu/RUS0013.kml
# Completed/maina irungu/BRA0036.kml
# Completed/marvin mwangi/NLD0003.kml
# Completed/marvin mwangi/KOR0014.kml
# Completed/marvin mwangi/TUR0024.kml
# Completed/marvin mwangi/BEL0006.kml
# Completed/marvin mwangi/VNM0004.kml
# Completed/marvin mwangi/PAK0001.kml
# Completed/marvin mwangi/MEX0003.kml
# Completed/marvin mwangi/IRN0013.kml
# Completed/regina nyambu/
# Completed/regina nyambu/BOL0001.kml
# Completed/regina nyambu/BRA0036.kml
# Completed/regina nyambu/CHN0175.kml
# Completed/regina nyambu/DZA0016.kml
# Completed/regina nyambu/CHN0252.kml
# Completed/regina nyambu/ALB0003.kml
# Completed/regina nyambu/MOZ0004.kml
# Completed/regina nyambu/CHN0100.kml
# Completed/regina nyambu/CHN0160.kml
# Completed/regina nyambu/CHN0043.kml
# Completed/regina nyambu/BOL0003.kml
# Completed/regina nyambu/CHN0052.kml
# Completed/regina nyambu/CHN0070.kml
# Completed/regina nyambu/UKR0006.kml
# Completed/regina nyambu/AGO0001.kml
# Completed/regina nyambu/CHN0096.kml
# Completed/regina nyambu/IND0144.kml
# Completed/regina nyambu/CHN0164.kml
# Completed/regina nyambu/LVA0001.kml
# Completed/regina nyambu/CHN0102.kml
# Completed/regina nyambu/ARG0002.kml
# Completed/regina nyambu/BOL0002.kml
# Completed/regina nyambu/RUS0005.kml
# Completed/regina nyambu/CHN0150.kml
# Completed/regina nyambu/BRA0037.kml
# Completed/regina nyambu/CHN0248.kml
# Completed/regina nyambu/CAN0014.kml
# Completed/regina nyambu/BRN0001.kml
# Completed/regina nyambu/CHN0082.kml
# Completed/regina nyambu/CHN0163.kml
# Completed/regina nyambu/CMR0001.kml
# Completed/regina nyambu/CHN0073.kml
# Completed/regina nyambu/Mar2001.kml
# Completed/regina nyambu/CHN0037.kml
# Completed/regina nyambu/NIC0001.kml
# Completed/regina nyambu/ARG0001.kml
# Completed/regina nyambu/CHN0101.kml
# Completed/regina nyambu/CHN0002.kml
# Completed/regina nyambu/CHN0044.kml
# Completed/regina nyambu/BOL0004.kml
# Completed/regina nyambu/CHN0170.kml
# Completed/regina nyambu/CHN0035.kml
# Completed/regina nyambu/CHN0079.kml
# Completed/regina nyambu/BEL0002.kml
# Completed/regina nyambu/CHN0345.kml
# Completed/regina nyambu/DZA0015.kml
# Completed/regina nyambu/CHN0211.kml
# Completed/regina nyambu/NIC0003.kml
# Completed/regina nyambu/CHN0040.kml
# Completed/isaack otieno/
# Completed/isaack otieno/TUR0030.kml
# Completed/isaack otieno/ETH0001.kml
# Completed/isaack otieno/ITA0004.kml
# Completed/isaack otieno/RUS0008.kml
# Completed/isaack otieno/TZA0003.kml
# Completed/isaack otieno/VNM0001.kml
# Completed/isaack otieno/ZAF0001.kml
# Completed/isaack otieno/UZB0001.kml
# Completed/isaack otieno/ESP0011.kml
# Completed/isaack otieno/ITA0002.kml
# Completed/isaack otieno/THA0003.kml
# Completed/isaack otieno/RUS0015.kml
# Completed/isaack otieno/TZA0001.kml
# Completed/isaack otieno/IND0014.kml
# Completed/isaack otieno/UKR0006.kml
# Completed/isaack otieno/ZWE0002.kml
# Completed/isaack otieno/CHN0096.kml
# Completed/isaack otieno/TUR0009.kml
# Completed/isaack otieno/VNM0003.kml
# Completed/isaack otieno/ESP0013.kml
# Completed/isaack otieno/RUS0011.kml
# Completed/isaack otieno/POL0001.kml
# Completed/isaack otieno/MEX0002.kml
# Completed/isaack otieno/TGO0002.kml
# Completed/isaack otieno/PRY0001.kml
# Completed/isaack otieno/ITA0001.kml
# Completed/isaack otieno/RUS0014.kml
# Completed/isaack otieno/RUS0018.kml
# Completed/isaack otieno/VNM0002.kml
# Completed/isaack otieno/TUR0008.kml
# Completed/isaack otieno/RUS0009.kml
# Completed/isaack otieno/ZAF0002.kml
# Completed/isaack otieno/ESP0012.kml
# Completed/isaack otieno/TGO0001.kml
# Completed/isaack otieno/MEX0001.kml
# Completed/isaack otieno/PRT0005.kml
# Completed/isaack otieno/ARE0003.kml
# Completed/isaack otieno/RUS0010.kml
# Completed/isaack otieno/ZMB0002.kml
# Completed/isaack otieno/ITA0003.kml
# Completed/isaack otieno/ESP0009.kml
# Completed/isaack otieno/RUS0007.kml
# Completed/isaack otieno/TUR0006.kml
# Completed/isaack otieno/UKR0007.kml
# Completed/isaack otieno/TUN0002.kml
# Completed/isaack otieno/VNM0004.kml
# Completed/isaack otieno/TGO0003.kml
# Completed/isaack otieno/MEX0003.kml
# Completed/isaack otieno/RUS0012.kml
# Completed/isaack otieno/YEM0002.kml
# Completed/caroline kioko/
# Completed/caroline kioko/IND0003.kml
# Completed/caroline kioko/PAK0002.kml
# Completed/caroline kioko/IND0146.kml
# Completed/caroline kioko/ITA0008.kml
# Completed/caroline kioko/Mar2004.kml
# Completed/caroline kioko/BRA0001.kml
# Completed/caroline kioko/IND0142.kml
# Completed/caroline kioko/ITA0004.kml
# Completed/caroline kioko/IND0007.kml
# Completed/caroline kioko/MOZ0004.kml
# Completed/caroline kioko/ITA0002.kml
# Completed/caroline kioko/IND0005.kml
# Completed/caroline kioko/CHN0052.kml
# Completed/caroline kioko/NGA0002.kml
# Completed/caroline kioko/IND0144.kml
# Completed/caroline kioko/ITA0006.kml
# Completed/caroline kioko/CHN0038.kml
# Completed/caroline kioko/Mar2002.kml
# Completed/caroline kioko/MEX0002.kml
# Completed/caroline kioko/ITA0001.kml
# Completed/caroline kioko/IND0004.kml
# Completed/caroline kioko/RUS0014.kml
# Completed/caroline kioko/ITA0010.kml
# Completed/caroline kioko/PAK0003.kml
# Completed/caroline kioko/CHN0033.kml
# Completed/caroline kioko/ITA0009.kml
# Completed/caroline kioko/NGA0001.kml
# Completed/caroline kioko/Mar2005.kml
# Completed/caroline kioko/BRN0001.kml
# Completed/caroline kioko/CHN0082.kml
# Completed/caroline kioko/CZE0001.kml
# Completed/caroline kioko/CHN0073.kml
# Completed/caroline kioko/NIC0001.kml
# Completed/caroline kioko/MEX0001.kml
# Completed/ephantus maina/CHN0039.kml
# Completed/ephantus maina/JPN0005.kml
# Completed/ephantus maina/CHN0022.kml
# Completed/ephantus maina/USA0022.kml
# Completed/.DS_Store
# Completed/emily waithera/
# Completed/emily waithera/IND0120.kml
# Completed/emily waithera/IND0065.kml
# Completed/emily waithera/IND0119.kml
# Completed/emily waithera/RUS0017.kml
# Completed/emily waithera/IND0070.kml
# Completed/emily waithera/ZAF0001.kml
# Completed/emily waithera/IND0069.kml
# Completed/emily waithera/IND0087.kml
# Completed/emily waithera/ESP0002.kml
# Completed/emily waithera/CHN0043.kml
# Completed/emily waithera/RUS0015.kml
# Completed/emily waithera/CHN0052.kml
# Completed/emily waithera/IND0067.kml
# Completed/emily waithera/ZWE0002.kml
# Completed/emily waithera/CHN0164.kml
# Completed/emily waithera/IND0072.kml
# Completed/emily waithera/RUS0020.kml
# Completed/emily waithera/IND0089.kml
# Completed/emily waithera/RUS0014.kml
# Completed/emily waithera/IND0066.kml
# Completed/emily waithera/CAN0014.kml
# Completed/emily waithera/BRN0001.kml
# Completed/emily waithera/CHN0082.kml
# Completed/emily waithera/IND0143.kml
# Completed/emily waithera/RUS0018.kml
# Completed/emily waithera/CMR0001.kml
# Completed/emily waithera/IND0071.kml
# Completed/emily waithera/CHN0073.kml
# Completed/emily waithera/ZAF0002.kml
# Completed/emily waithera/IND0088.kml
# Completed/emily waithera/RUS0010.kml
# Completed/emily waithera/ZMB0002.kml
# Completed/emily waithera/CHN0044.kml
# Completed/emily waithera/RUS0016.kml
# Completed/emily waithera/IND0068.kml
# Completed/emily waithera/IND0086.kml
# Completed/emily waithera/ZWE0003.kml
# Completed/emily waithera/CHN0079.kml
# Completed/emily waithera/CHN0165.kml
# Completed/emily waithera/CHN0066.kml
# Completed/emily waithera/VNM0004.kml
# Completed/emily waithera/RUS0021.kml
# Completed/emily waithera/YEM0002.kml
# Completed/emily waithera/CHN0040.kml
# Completed/emily waithera/ESP0005.kml
# Completed/benice ruga/
# Completed/benice ruga/EGY0009.kml
# Completed/benice ruga/IND0120.kml
# Completed/benice ruga/IRQ0002.kml
# Completed/benice ruga/IND0065.kml
# Completed/benice ruga/IND0119.kml
# Completed/benice ruga/IND0056.kml
# Completed/benice ruga/ETH0001.kml
# Completed/benice ruga/DEU0013.kml
# Completed/benice ruga/IND0007.kml
# Completed/benice ruga/RUS0017.kml
# Completed/benice ruga/CHN0252.kml
# Completed/benice ruga/IND0070.kml
# Completed/benice ruga/IND0016.kml
# Completed/benice ruga/IND0133.kml
# Completed/benice ruga/IND0005.kml
# Completed/benice ruga/IND0131.kml
# Completed/benice ruga/IND0067.kml
# Completed/benice ruga/IND0058.kml
# Completed/benice ruga/IND0063.kml
# Completed/benice ruga/IND0072.kml
# Completed/benice ruga/CHN0137.kml
# Completed/benice ruga/IRQ0008.kml
# Completed/benice ruga/IND0018.kml
# Completed/benice ruga/IND0135.kml
# Completed/benice ruga/IND0089.kml
# Completed/moses njau/ITA0005.kml
# Completed/moses njau/CHN0136.kml
# Completed/moses njau/ESP0012.kml
# Completed/moses njau/ITA0003.kml
# Completed/moses njau/DOM0001.kml
# Completed/moses njau/CHN0116.kml
# Completed/moses njau/CHN0035.kml
# Completed/moses njau/IND0015.kml
# Completed/moses njau/UKR0007.kml
# Completed/moses njau/ESP0010.kml
# Completed/moses njau/ITA0007.kml
# Completed/moses njau/CHN0165.kml
# Completed/moses njau/CHN0066.kml
# Completed/moses njau/CHN0174.kml
# Completed/moses njau/CHN0013.kml
# Completed/moses njau/PRT0007.kml
# Completed/john otieno/
# Completed/john otieno/LBN0002.kml
# Completed/john otieno/IND0120.kml
# Completed/john otieno/CHN0014.kml
# Completed/john otieno/JPN0006.kml
# Completed/john otieno/IRN0005.kml
# Completed/john otieno/CHN0085.kml
# Completed/john otieno/EGY0010.kml
# Completed/john otieno/CHN0067.kml
# Completed/john otieno/IND0119.kml
# Completed/john otieno/Mar2004.kml
# Completed/john otieno/IND0137.kml
# Completed/john otieno/BRA0001.kml
# Completed/john otieno/ETH0001.kml
# Completed/john otieno/CHN0009.kml
# Completed/john otieno/DEU0013.kml
# Completed/john otieno/NLD0004.kml
# Completed/john otieno/IND0133.kml
# Completed/john otieno/IND0140.kml
# Completed/john otieno/CHN0007.kml
# Completed/john otieno/NLD0002.kml
# Completed/john otieno/RUS0006.kml
# Completed/john otieno/BOL0003.kml
# Completed/john otieno/IND0131.kml
# Completed/john otieno/CHN0096.kml
# Completed/john otieno/IND0139.kml
# Completed/john otieno/CHN0083.kml
# Completed/john otieno/LVA0001.kml
# Completed/john otieno/RUS0019.kml
# Completed/john otieno/KOR0017.kml
# Completed/john otieno/VNM0003.kml
# Completed/john otieno/IRQ0008.kml
# Completed/john otieno/Mar2002.kml
# Completed/john otieno/IND0135.kml
# Completed/john otieno/CHN0021.kml
# Completed/john otieno/PRT0006.kml
# Completed/john otieno/IND0001.kml
# Completed/john otieno/JOR0001.kml
# Completed/john otieno/EGY0007.kml
# Completed/john otieno/CHN0006.kml
# Completed/john otieno/IND0121.kml
# Completed/john otieno/JPN0007.kml
# Completed/john otieno/SLV0002.kml
# Completed/john otieno/SEN0001.kml
# Completed/john otieno/IND0138.kml
# Completed/john otieno/CHN0136.kml
# Completed/john otieno/IND0134.kml
# Completed/john otieno/ESP0038.kml
# Completed/john otieno/Mar2001.kml
# Completed/john otieno/FRA0020.kml
# Completed/john otieno/DEU0012.kml
# Completed/john otieno/IND0141.kml
# Completed/john otieno/NLD0003.kml
# Completed/john otieno/DOM0001.kml
# Completed/john otieno/KOR0014.kml
# Completed/john otieno/IND0132.kml
# Completed/john otieno/GHA0001.kml
# Completed/john otieno/JPN0009.kml
# Completed/john otieno/ESP0010.kml
# Completed/john otieno/KAZ0003.kml
# Completed/john otieno/CHN0174.kml
# Completed/john otieno/IND0136.kml
# Completed/john otieno/Mar2003.kml
# Completed/john otieno/PAK0001.kml
# Completed/john otieno/JPN0005.kml
# Completed/john otieno/CHN0022.kml
# Completed/john otieno/PRT0007.kml
# Completed/fiona atieno/
# Completed/fiona atieno/TUR0030.kml
# Completed/fiona atieno/CHN0014.kml
# Completed/fiona atieno/BOL0001.kml
# Completed/fiona atieno/BRA0036.kml
# Completed/fiona atieno/TUR0029.kml
# Completed/fiona atieno/TZA0003.kml
# Completed/fiona atieno/ZAF0001.kml
# Completed/fiona atieno/ESP0002.kml
# Completed/fiona atieno/IND0140.kml
# Completed/fiona atieno/CHN0007.kml
# Completed/fiona atieno/ESP0008.kml
# Completed/fiona atieno/THA0003.kml
# Completed/fiona atieno/TZA0001.kml
# Completed/fiona atieno/USA0034.kml
# Completed/fiona atieno/UKR0006.kml
# Completed/fiona atieno/RUS0019.kml
# Completed/fiona atieno/TUR0009.kml
# Completed/fiona atieno/USA0038.kml
# Completed/fiona atieno/RUS0020.kml
# Completed/fiona atieno/TGO0002.kml
# Completed/fiona atieno/SEN0001.kml
# Completed/fiona atieno/RUS0018.kml
# Completed/fiona atieno/TUR0008.kml
# Completed/fiona atieno/ZAF0002.kml
# Completed/fiona atieno/RUS0027.kml
# Completed/fiona atieno/TGO0001.kml
# Completed/fiona atieno/ARE0003.kml
# Completed/fiona atieno/RUS0016.kml
# Completed/fiona atieno/TUR0006.kml
# Completed/fiona atieno/TUR0024.kml
# Completed/fiona atieno/UKR0007.kml
# Completed/fiona atieno/TUN0002.kml
# Completed/fiona atieno/BEL0002.kml
# Completed/fiona atieno/USA0093.kml
# Completed/fiona atieno/RUS0021.kml
# Completed/fiona atieno/TGO0003.kml
# Completed/fiona atieno/CHN0022.kml
# Completed/fiona atieno/USA0022.kml
# Completed/fiona atieno/ESP0005.kml
# Completed/vincent kipngetich/
# Completed/vincent kipngetich/RUS0013.kml
# Completed/vincent kipngetich/CHN0104.kml
# Completed/vincent kipngetich/CHN0014.kml
# Completed/vincent kipngetich/RUS0004.kml
# Completed/vincent kipngetich/CHN0131.kml
# Completed/vincent kipngetich/IRQ0002.kml
# Completed/vincent kipngetich/JPN0006.kml
# Completed/vincent kipngetich/IND0146.kml
# Completed/vincent kipngetich/CHN0162.kml
# Completed/vincent kipngetich/CHN0108.kml
# Completed/vincent kipngetich/RUS0008.kml
# Completed/vincent kipngetich/CHN0117.kml
# Completed/vincent kipngetich/ESP0011.kml
# Completed/vincent kipngetich/COG0001.kml
# Completed/vincent kipngetich/CHN0100.kml
# Completed/vincent kipngetich/CHN0001.kml
# Completed/vincent kipngetich/CHN0007.kml
# Completed/vincent kipngetich/CHN0160.kml
# Completed/vincent kipngetich/CHN0043.kml
# Completed/vincent kipngetich/CHN0106.kml
# Completed/vincent kipngetich/RUS0006.kml
# Completed/vincent kipngetich/CHN0115.kml
# Completed/vincent kipngetich/JPN0008.kml
# Completed/vincent kipngetich/IND0014.kml
# Completed/vincent kipngetich/ITA0006.kml
# Completed/vincent kipngetich/CHN0137.kml
# Completed/vincent kipngetich/RUS0002.kml
# Completed/vincent kipngetich/ESP0013.kml
# Completed/vincent kipngetich/CHN0003.kml
# Completed/vincent kipngetich/CHN0006.kml
# Completed/vincent kipngetich/CHN0105.kml
# Completed/vincent kipngetich/RUS0005.kml
# Completed/vincent kipngetich/JPN0007.kml
# Completed/vincent kipngetich/CHN0114.kml
# Completed/vincent kipngetich/CHN0163.kml
# Completed/vincent kipngetich/CHN0136.kml
# Completed/vincent kipngetich/RUS0009.kml
# Completed/vincent kipngetich/ESP0038.kml
# Completed/vincent kipngetich/Mar2001.kml
# Completed/vincent kipngetich/IRQ0007.kml
# Completed/vincent kipngetich/RUS0001.kml
# Completed/vincent kipngetich/CHN0110.kml
# Completed/vincent kipngetich/CHN0101.kml
# Completed/vincent kipngetich/RUS0010.kml
# Completed/vincent kipngetich/ESP0009.kml
# Completed/vincent kipngetich/CHN0143.kml
# Completed/vincent kipngetich/RUS0007.kml
# Completed/vincent kipngetich/CHN0116.kml
# Completed/vincent kipngetich/IRQ0005.kml
# Completed/vincent kipngetich/JPN0009.kml
# Completed/vincent kipngetich/ESP0010.kml
# Completed/vincent kipngetich/CHN0079.kml
# Completed/vincent kipngetich/BEL0002.kml
# Completed/vincent kipngetich/IRQ0009.kml
# Completed/vincent kipngetich/RUS0003.kml
# Completed/vincent kipngetich/CHN0013.kml
# Completed/vincent kipngetich/NIC0003.kml
# Completed/vincent kipngetich/RUS0012.kml
# Completed/vincent kipngetich/IND0002.kml
# Completed/vincent kipngetich/CHN0040.kml
# Completed/vincent kipngetich/IRQ0010.kml
# Completed/joshua mwangi/
# Completed/joshua mwangi/CHN0104.kml
# Completed/joshua mwangi/PAK0002.kml
# Completed/joshua mwangi/IND0065.kml
# Completed/joshua mwangi/IND0056.kml
# Completed/joshua mwangi/IND0142.kml
# Completed/joshua mwangi/CHN0108.kml
# Completed/joshua mwangi/RUS0008.kml
# Completed/joshua mwangi/TZA0003.kml
# Completed/joshua mwangi/KOR0015.kml
# Completed/joshua mwangi/BEL0007.kml
# Completed/joshua mwangi/IND0140.kml
# Completed/joshua mwangi/CHN0106.kml
# Completed/joshua mwangi/THA0003.kml
# Completed/joshua mwangi/CRI0002.kml
# Completed/joshua mwangi/TZA0001.kml
# Completed/joshua mwangi/CHN0115.kml
# Completed/joshua mwangi/PAN0001.kml
# Completed/joshua mwangi/IND0058.kml
# Completed/joshua mwangi/IND0139.kml
# Completed/joshua mwangi/IND0063.kml
# Completed/joshua mwangi/IND0018.kml
# Completed/joshua mwangi/TGO0002.kml
# Completed/joshua mwangi/CHN0105.kml
# Completed/joshua mwangi/IND0138.kml
# Completed/joshua mwangi/IND0143.kml
# Completed/joshua mwangi/KOR0016.kml
# Completed/joshua mwangi/RUS0001.kml
# Completed/joshua mwangi/CHN0110.kml
# Completed/joshua mwangi/TGO0001.kml
# Completed/joshua mwangi/IND0141.kml
# Completed/joshua mwangi/IND0060.kml
# Completed/joshua mwangi/RUS0007.kml
# Completed/joshua mwangi/TUR0006.kml
